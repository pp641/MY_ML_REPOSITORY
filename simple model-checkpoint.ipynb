# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/PRAJJWAL PANDEY/Downloads/slr01.xls")
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
df
# Out:
#             X          Y
# 0   12.400000  11.200000
# 1   14.300000  12.500000
# 2   14.500000  12.700000
# 3   14.900000  13.100000
# 4   16.100000  14.100000
# 5   16.900000  14.800000
# 6   16.500000  14.400000
# 7   15.400000  13.400000
# 8   17.000000  14.900000
# 9   17.900000  15.600000
# 10  18.799999  16.400000
# 11  20.299999  17.700001
# 12  22.400000  19.600000
# 13  19.400000  16.900000
# 14  15.500000  14.000000
# 15  16.700001  14.600000
# 16  17.299999  15.100000
# 17  18.400000  16.100000
# 18  19.200001  16.799999
# 19  17.400000  15.200000
# 20  19.500000  17.000000
# 21  19.700001  17.200001
# 22  21.200001  18.600000

# %%
y = df.X

# %%
y = np.array(df)

# %%
x = np.array(df.X)
y = np.array(df.Y)

# %%
df.shape
# Out:
# (23, 2)

# %%
x = x.reshape(23,1)
y = y.reshape(23,1)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(model.score(x,y))
# Out:
# 0.9970831247402355

# %%
print(model.intercept_)
# Out:
# [0.43458449]

# %%
print(model.coef_)
# Out:
# [[0.85114404]]

# %%
ypred= model.predict(x)

# %%
ypred
# Out:
# array([[10.98877024],
#        [12.60594439],
#        [12.77617304],
#        [13.11663033],
#        [14.13800382],
#        [14.81891841],
#        [14.47846112],
#        [13.54220235],
#        [14.90403313],
#        [15.67006245],
#        [16.43609176],
#        [17.71280781],
#        [19.50021062],
#        [16.9467785 ],
#        [13.62731708],
#        [14.64869057],
#        [15.1593757 ],
#        [16.09563446],
#        [16.77655066],
#        [15.24449043],
#        [17.03189323],
#        [17.20212268],
#        [18.47883874]])

# %%
for i in x:
    print( np.sum(model.coef_*i) + model.intercept_)
# Out:
# [10.98877024]
# [12.60594439]
# [12.77617304]
# [13.11663033]
# [14.13800382]
# [14.81891841]
# [14.47846112]
# [13.54220235]
# [14.90403313]
# [15.67006245]
# [16.43609176]
# [17.71280781]
# [19.50021062]
# [16.9467785]
# [13.62731708]
# [14.64869057]
# [15.1593757]
# [16.09563446]
# [16.77655066]
# [15.24449043]
# [17.03189323]
# [17.20212268]
# [18.47883874]

# %%
plt.plot(df.X,df.Y)

# %%
plt.plot(x,ypred)

# %%
# !pip install multiset

# %%
df = pd.read_csv("C:/Users/PRAJJWAL PANDEY/Desktop/income.data.csv")
df
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# 5             6  3.729643   2.458556
# 6             7  4.674517   3.192992
# 7             8  4.498104   1.907137
# 8             9  3.121631   2.942450
# 9            10  4.639914   3.737942
# 10           11  4.632840   3.175406
# 11           12  2.773179   2.009046
# 12           13  7.119479   5.951814
# 13           14  7.466653   5.960547
# 14           15  2.117742   1.445799
# 15           16  2.559166   2.898583
# 16           17  2.354793   1.231168
# 17           18  2.388157   2.312988
# 18           19  4.755680   2.666116
# 19           20  1.994275   2.584729
# 20           21  7.310916   5.747444
# 21           22  3.528319   2.546525
# 22           23  2.428752   1.200786
# 23           24  3.542748   3.078293
# ...

# %%
x = np.array(df['income']).reshape(498,1)
y = np.array(df['happiness'])

# %%
p,q = x.shape,y.shape

# %%
print(p,q)
# Out:
# (498, 1) (498,)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([0.71382551])

# %%
model.intercept_
# Out:
# 0.20427039623160193

# %%
pred = model.predict(x)

# %%
pred  = pred.reshape(498,1)

# %%
pred.shape
# Out:
# (498, 1)

# %%
p1 = np.array(pred)

# %%
for i in x:
    print( i*model.coef_ + model.intercept_)
# Out:
# [2.96152667]
# [3.75867986]
# [3.71911648]
# [2.49877145]
# [5.34125092]
# [2.86658506]
# [3.54106017]
# [3.41513166]
# [2.43256991]
# [3.51635969]
# [3.51130944]
# [2.18383624]
# [5.28633585]
# [5.53415794]
# [1.7159689]
# [2.03106825]
# [1.88518187]
# [1.90899797]
# [3.5989963]
# [1.6278348]
# [5.42298877]
# [2.72287448]
# [1.9379753]
# [2.73317421]
# [3.93558]
# [4.98118583]
# [2.98848252]
# [1.83968425]
# [1.9035411]
# [2.02424619]
# [5.15343384]
# [1.52887726]
# [2.76620668]
# [5.07718449]
# [1.68231885]
# [3.9334414]
# [1.80546213]
# [5.25541848]
# [3.19567934]
# [1.6008601]
# [3.81748253]
# [3.04685917]
# [2.39218744]
# [2.83320231]
# [2.9092617]
# [4.02945835]
# [3.91339326]
# [3.94556523]
# [5.27358764]
# [2.64842401]
# [1.81280411]
# [4.03775389]
# [4.64826679]
# [4.11807734]
# [3.08396537]
# [4.85143061]
# [4.50807707]
# [5.16472447]
# [5.34027157]
# [2.17252896]
# [5.1696974]
# [3.53797301]
# [4.75012017]
# [4.60620474]
# [4.54015955]
# [4.11940272]
# [1.3389494]
# ...

# %%
pred
# Out:
# array([[2.96152667],
#        [3.75867986],
#        [3.71911648],
#        [2.49877145],
#        [5.34125092],
#        [2.86658506],
#        [3.54106017],
#        [3.41513166],
#        [2.43256991],
#        [3.51635969],
#        [3.51130944],
#        [2.18383624],
#        [5.28633585],
#        [5.53415794],
#        [1.7159689 ],
#        [2.03106825],
#        [1.88518187],
#        [1.90899797],
#        [3.5989963 ],
#        [1.6278348 ],
#        [5.42298877],
#        [2.72287448],
#        [1.9379753 ],
#        [2.73317421],
#        [3.93558   ],
#        [4.98118583],
#        [2.98848252],
#        [1.83968425],
#        [1.9035411 ],
#        [2.02424619],
#        [5.15343384],
#        [1.52887726],
#        [2.76620668],
#        [5.07718449],
#        [1.68231885],
#        [3.9334414 ],
#        [1.80546213],
#        [5.25541848],
#        [3.19567934],
#        [1.6008601 ],
#        [3.81748253],
#        [3.04685917],
#        [2.39218744],
# ...

# %%
model.score(x,y)
# Out:
# 0.7493217544889172
