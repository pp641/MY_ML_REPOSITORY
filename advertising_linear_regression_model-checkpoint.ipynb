# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\PRAJJWAL PANDEY\Desktop\ml internshala\ml datasets\DataSets-master\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
df = np.array(df)

# %%
df.shape
# Out:
# (200, 5)

# %%
y = df[:,4:]

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %%
x = df[:,1:4]

# %%
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(x,y)
# Out:
# 0.8972106381789521

# %%
model.intercept_
# Out:
# array([2.93888937])

# %%
model.coef_
# Out:
# array([[ 0.04576465,  0.18853002, -0.00103749]])

# %%
ypred = model.predict(x)

# %%
ypred
# Out:
# array([[20.52397441],
#        [12.33785482],
#        [12.30767078],
#        [17.59782951],
#        [13.18867186],
#        [12.47834763],
#        [11.72975995],
#        [12.12295317],
#        [ 3.72734086],
#        [12.55084872],
#        [ 7.0322992 ],
#        [17.28512918],
#        [10.57712073],
#        [ 8.82630048],
#        [18.43436638],
#        [20.81929952],
#        [12.82365674],
#        [23.22495716],
#        [ 9.95168206],
#        [14.16607293],
#        [18.10076728],
#        [14.7405382 ],
#        [ 6.4891503 ],
#        [16.5459329 ],
#        [ 8.14651887],
#        [15.6100386 ],
#        [14.98951429],
#        [17.05167344],
#        [19.41053803],
#        [ 9.14402389],
#        [21.6339338 ],
#        [11.3460929 ],
#        [ 7.63888314],
#        [18.86426829],
#        [ 7.57483051],
#        [17.00682618],
#        [23.40590052],
#        [15.62347779],
#        [ 9.90868103],
#        [20.44761039],
#        [16.37766467],
# ...

# %%
for i in x:
    print(np.sum(i*model.coef_) + model.intercept_)
# Out:
# [20.52397441]
# [12.33785482]
# [12.30767078]
# [17.59782951]
# [13.18867186]
# [12.47834763]
# [11.72975995]
# [12.12295317]
# [3.72734086]
# [12.55084872]
# [7.0322992]
# [17.28512918]
# [10.57712073]
# [8.82630048]
# [18.43436638]
# [20.81929952]
# [12.82365674]
# [23.22495716]
# [9.95168206]
# [14.16607293]
# [18.10076728]
# [14.7405382]
# [6.4891503]
# [16.5459329]
# [8.14651887]
# [15.6100386]
# [14.98951429]
# [17.05167344]
# [19.41053803]
# [9.14402389]
# [21.6339338]
# [11.3460929]
# [7.63888314]
# [18.86426829]
# [7.57483051]
# [17.00682618]
# [23.40590052]
# [15.62347779]
# [9.90868103]
# [20.44761039]
# [16.37766467]
# [17.2959832]
# [21.59580326]
# [13.96385684]
# [8.88787996]
# [15.16152314]
# [8.87338673]
# [21.7226299]
# [16.26362018]
# [8.1681656]
# [12.63121132]
# [9.33981296]
# [20.66297563]
# [19.94469957]
# [20.37443008]
# [21.2926106]
# [8.52771254]
# [12.77458802]
# [21.89805198]
# [18.13348698]
# [5.74215558]
# [22.89067208]
# [16.78426073]
# [13.21069202]
# ...

# %%
# Out:
# array([230.1,  37.8,  69.2])
